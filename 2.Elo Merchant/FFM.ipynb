# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('/home/tung/Desktop/input/train_final.csv')

# %%
train.head()
# Out:
#    feature_1  feature_2  feature_3  elapsed_time  hist_transactions_count  \
# 0   1.597335   0.338839   0.876431     -0.466376                 0.311084
# 1   0.754276  -0.992082  -1.140992      0.047738                 0.150070
# 2  -0.931842   0.338839  -1.140992      0.568661                -0.574497
# 3   0.754276   1.669759  -1.140992     -0.779611                      NaN
# 4  -1.774901   1.669759  -1.140992     -0.987299                -0.332975
#
#    hist_category_1_sum  hist_category_1_mean  hist_category_2_1.0_mean  \
# 0            -0.234615             -0.548342                  1.203092
# 1             0.011414              0.048638                  0.798033
# 2            -0.234615             -0.548342                 -1.024733
# 3                  NaN                   NaN                       NaN
# 4             0.134429              1.421691                 -1.024733
#
#    hist_category_2_2.0_mean  hist_category_2_3.0_mean         ...          \
# ...

# %%
print(list(train.columns))
# Out:
# ['feature_1', 'feature_2', 'feature_3', 'elapsed_time', 'hist_transactions_count', 'hist_category_1_sum', 'hist_category_1_mean', 'hist_category_2_1.0_mean', 'hist_category_2_2.0_mean', 'hist_category_2_3.0_mean', 'hist_category_2_4.0_mean', 'hist_category_2_5.0_mean', 'hist_category_3_A_mean', 'hist_category_3_B_mean', 'hist_category_3_C_mean', 'hist_merchant_id_nunique', 'hist_purchase_amount_sum', 'hist_purchase_amount_mean', 'hist_purchase_amount_max', 'hist_purchase_amount_min', 'hist_purchase_amount_std', 'hist_installments_sum', 'hist_installments_mean', 'hist_installments_max', 'hist_installments_min', 'hist_installments_std', 'hist_purchase_month_mean', 'hist_purchase_month_max', 'hist_purchase_month_min', 'hist_purchase_month_std', 'hist_purchase_date_ptp', 'hist_purchase_date_min', 'hist_purchase_date_max', 'hist_month_lag_min', 'hist_month_lag_max', 'hist_month_lag_std', 'hist_month_lag_sum', 'auth_transactions_count', 'auth_category_1_sum', 'auth_category_1_mean', 'auth_
# ...

# %%
train.replace([np.inf, -np.inf], np.nan,inplace=True)
train.fillna(0,inplace = True)

# %%
train.shape
# Out:
# (201917, 133)

# %%
def numeric_to_cat(df,col_name):
#     cat_name = [col_name+'_'+str(x) for x in range(4)]
#     print(cat_name)
    df = pd.qcut(df,[0, .50, .75, 1.],
#                  labels=cat_name,
                 duplicates='drop'
                )
    return df

# %%
excluded =['card_id']
col_to_cat = [col for col in train.columns if col not in excluded]
for col in col_to_cat:
    train[col] = numeric_to_cat(train[col],col)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-1c9cdf76345d> in <module>
#       2 col_to_cat = [col for col in train.columns if col not in excluded]
#       3 for col in col_to_cat:
# ----> 4     train[col] = numeric_to_cat(train[col],col)
#
# <ipython-input-69-b1348436d7f3> in numeric_to_cat(df, col_name)
#       4     df = pd.qcut(df,[0, .50, .75, 1.],
#       5 #                  labels=cat_name,
# ----> 6                  duplicates='drop'
#       7                 )
#       8     return df
#
# ~/miniconda3/envs/kaggle/lib/python3.6/site-packages/pandas/core/reshape/tile.py in qcut(x, q, labels, retbins, precision, duplicates)
#     304     fac, bins = _bins_to_cuts(x, bins, labels=labels,
#     305                               precision=precision, include_lowest=True,
# --> 306                               dtype=dtype, duplicates=duplicates)
# ...

# %%
train.head()
# Out:
#                        feature_1        feature_2        feature_3  \
# 0               (-0.0888, 1.597]  (-0.993, 0.339]  (-1.142, 0.876]
# 1               (-0.0888, 1.597]  (-0.993, 0.339]  (-1.142, 0.876]
# 2  (-1.7759999999999998, -0.932]  (-0.993, 0.339]  (-1.142, 0.876]
# 3               (-0.0888, 1.597]    (0.339, 1.67]  (-1.142, 0.876]
# 4  (-1.7759999999999998, -0.932]    (0.339, 1.67]  (-1.142, 0.876]
#
#                    elapsed_time hist_transactions_count hist_category_1_sum  \
# 0               (-0.78, -0.466]         (-0.172, 0.311]    (-0.236, 0.0114]
# 1              (-0.466, 0.0477]         (-0.172, 0.311]    (-0.236, 0.0114]
# 2               (0.0477, 0.569]        (-0.656, -0.574]    (-0.236, 0.0114]
# 3  (-1.3019999999999998, -0.78]                     NaN                 NaN
# 4  (-1.3019999999999998, -0.78]        (-0.413, -0.172]   (0.0114, 185.517]
#
#   hist_category_1_mean       hist_category_2_1.0_mean  \
# ...
